# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sqlite3
import matplotlib.pyplot as plt

# %%
database = r'C:\Users\DELL\Documents\wdi\database.sqlite'
conn = sqlite3.connect(database)
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table       Country       Country         2
# 1  table  CountryNotes  CountryNotes       186
# 2  table        Series        Series       948
# 3  table    Indicators    Indicators      4448
# 4  table   SeriesNotes   SeriesNotes   1317550
# 5  table     Footnotes     Footnotes   1317587
#
#                                                  sql
# 0  CREATE TABLE Country (\n    CountryCode TEXT,\...
# 1  CREATE TABLE CountryNotes (\n    Countrycode T...
# 2  CREATE TABLE Series (\n    SeriesCode TEXT,\n ...
# 3  CREATE TABLE Indicators (\n    CountryName TEX...
# 4  CREATE TABLE SeriesNotes (\n    Seriescode TEX...
# 5  CREATE TABLE Footnotes (\n    Countrycode TEXT...

# %%
countries = pd.read_sql("""SELECT *
                        FROM Country;""", conn)
countries.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
#
#                        Region           IncomeGroup Wb2Code  \
# 0                  South Asia            Low income      AF
# ...

# %%
countries = pd.read_sql("""SELECT 
                        ShortName,
                        LongName,
                        Region,
                        CurrencyUnit,
                        Country.Countrycode
                        FROM Country
                        INNER JOIN CountryNotes
                        ON Country.Countrycode = CountryNotes.Countrycode;""", conn)
countries.head()
# Out:
#      ShortName                      LongName      Region    CurrencyUnit  \
# 0  Afghanistan  Islamic State of Afghanistan  South Asia  Afghan afghani
# 1  Afghanistan  Islamic State of Afghanistan  South Asia  Afghan afghani
# 2  Afghanistan  Islamic State of Afghanistan  South Asia  Afghan afghani
# 3  Afghanistan  Islamic State of Afghanistan  South Asia  Afghan afghani
# 4  Afghanistan  Islamic State of Afghanistan  South Asia  Afghan afghani
#
#   CountryCode
# 0         AFG
# 1         AFG
# 2         AFG
# 3         AFG
# 4         AFG

# %%
mex_df = pd.read_sql("""SELECT 
                        ShortName
                        LongName,
                        Region,
                        CurrencyUnit,
                        Country.Countrycode,
                        SeriesCode,
                        LatestPopulationCensus
                        FROM Country
                        JOIN CountryNotes
                        ON Country.Countrycode = CountryNotes.Countrycode
                        WHERE Country.ShortName = 'Mexico';""", conn)
mex_df
# Out:
#    LongName                     Region  CurrencyUnit CountryCode  \
# 0    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 1    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 2    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 3    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 4    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 5    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 6    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 7    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 8    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 9    Mexico  Latin America & Caribbean  Mexican peso         MEX
# 10   Mexico  Latin America & Caribbean  Mexican peso         MEX
# 11   Mexico  Latin America & Caribbean  Mexican peso         MEX
# 12   Mexico  Latin America & Caribbean  Mexican peso         MEX
# ...

# %%
mex_df.to_sql('MexicoData', con=conn)

# %%
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table       Country       Country         2
# 1  table  CountryNotes  CountryNotes       186
# 2  table        Series        Series       948
# 3  table    Indicators    Indicators      4448
# 4  table   SeriesNotes   SeriesNotes   1317550
# 5  table     Footnotes     Footnotes   1317587
# 6  table    MexicoData    MexicoData   1378401
#
#                                                  sql
# 0  CREATE TABLE Country (\n    CountryCode TEXT,\...
# 1  CREATE TABLE CountryNotes (\n    Countrycode T...
# 2  CREATE TABLE Series (\n    SeriesCode TEXT,\n ...
# 3  CREATE TABLE Indicators (\n    CountryName TEX...
# 4  CREATE TABLE SeriesNotes (\n    Seriescode TEX...
# 5  CREATE TABLE Footnotes (\n    Countrycode TEXT...
# 6  CREATE TABLE "MexicoData" (\n"index" INTEGER,\...

# %%
mex_df = pd.read_sql("""SELECT 
                        CountryCode,
                        Seriescode,
                        IndicatorName
                        FROM Series
                        JOIN CountryNotes
                        ON CountryNotes. = CountryNotes.Countrycode;""", conn)
mex_df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1399             else:
# -> 1400                 cur.execute(*args)
#    1401             return cur
#
# OperationalError: RIGHT and FULL OUTER JOINs are not currently supported
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-26-24aa71d7454a> in <module>()
#       8                         FROM MexicoData
#       9                         OUTER JOIN CountryNotes
# ---> 10                         ON MexicoData.Countrycode = CountryNotes.Countrycode;""", conn)
#      11 mex_df
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
# ...

# %%
import pyodbc
from sqlalchemy import create_engine

# %%
engine = create_engine('mssql+pyodbc://localhost/Sandbox?driver=SQL+Server+Native+Client+11.0')

# %%
mex_df.to_sql('mex_df',engine, if_exists = 'append',index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-efc69cc3944e> in <module>()
# ----> 1 mex_df.to_sql('mex_df',engine, if_exists = 'append',index = False)
#
# NameError: name 'mex_df' is not defined
